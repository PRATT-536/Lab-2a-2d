# %% [markdown]
# # Robo Advisor - Dashboard

# %% [markdown]
# ## Content
# * [1. Loading the Libraries and the data](#1)
# * [2. Code for the dashboard Interface](#2)
# * [3. Code for the underlying functions within the interface](#3)
#
#
# #### Note that the dashboard opens up in a separate browser. The url for the browser will be produced in the end of the code and would look something like "http://127.0.0.1:8080"

# %% [markdown]
# <a id='1'></a>
# ## 1. Loading the Libraries and the data

# %% [markdown]
# Checking if the additional packages needed are present, if not install them. These are checked separately as they aren't included in requirement.txt as they aren't used for all case studies.

# %%
import os
import socket
import sys
import signal
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import pip
# !pip install -r requirements.txt
# !pip install --upgrade setuptools
# !pip install werkzeug==2.2.2
#from werkzeug.debug import debugtraceback
#!pip install debugtraceback
#from werkzeug.debug.tbtools import DebugTraceback

# !pip install dash==2.8.1
import dash
from dash import dcc
from dash import html
import dash_daq as daq
from dash.dependencies import Input,Output,State
import pandas as pd
import numpy as np
import plotly.graph_objs as go
from pickle import load
import cvxopt as opt
from cvxopt import blas, solvers

## pause

# !pip install --upgrade pkg_resources
import pkg_resources
installedPackages = {pkg.key for pkg in pkg_resources.working_set}
required = {'dash', 'dash-core-components', 'dash-html-components', 'dash-daq', 'cvxopt' }
# Out:
# Requirement already satisfied: absl-py==1.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: appdirs==1.4.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: astunparse==1.6.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: async-generator==1.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (1.10)
# Requirement already satisfied: cachetools==5.3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (5.3.0)
# Requirement already satisfied: certifi==2022.12.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 6)) (2022.12.7)
# Requirement already satisfied: certipy==0.1.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 7)) (0.1.3)
# Requirement already satisfied: cycler==0.11.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (0.11.0)
# Requirement already satisfied: Dash==2.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 9)) (2.8.1)
# Requirement already satisfied: et-xmlfile==1.1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: flatbuffers==23.1.21 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 11)) (23.1.21)
# Requirement already satisfied: fonttools==4.38.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 12)) (4.38.0)
# Requirement already satisfied: frozendict==2.3.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 13)) (2.3.5)
# Requirement already satisfied: gast==0.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 14)) (0.4.0)
# Requirement already satisfied: google-auth==2.16.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 15)) (2.16.1)
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 16)) (0.4.6)
# Requirement already satisfied: google-pasta==0.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 17)) (0.2.0)
# Requirement already satisfied: grpcio==1.51.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 18)) (1.51.1)
# Requirement already satisfied: h5py==3.8.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 19)) (3.8.0)
# Requirement already satisfied: html5lib==1.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 20)) (1.1)
# Requirement already satisfied: inflection==0.5.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 21)) (0.5.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 22)) (0.2.0)
# Requirement already satisfied: joblib==1.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 23)) (1.2.0)
# Requirement already satisfied: jupyter==1.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 24)) (1.0.0)
# Requirement already satisfied: jupyter-console==6.5.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 25)) (6.5.1)
# Requirement already satisfied: jupyter_core==4.12.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 26)) (4.12.0)
# Requirement already satisfied: keras==2.11.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 27)) (2.11.0)
# Requirement already satisfied: kiwisolver==1.4.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 28)) (1.4.4)
# Requirement already satisfied: libclang==15.0.6.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 29)) (15.0.6.1)
# Requirement already satisfied: lxml==4.9.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 30)) (4.9.2)
# Requirement already satisfied: Markdown==3.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 31)) (3.4.1)
# Requirement already satisfied: matplotlib==3.5.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 32)) (3.5.3)
# Requirement already satisfied: more-itertools==9.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 33)) (9.0.0)
# Requirement already satisfied: multitasking==0.0.11 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 34)) (0.0.11)
# Requirement already satisfied: nteract-on-jupyter==2.1.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 35)) (2.1.3)
# Requirement already satisfied: numpy==1.21.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 36)) (1.21.6)
# Requirement already satisfied: openpyxl==3.1.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 37)) (3.1.1)
# Requirement already satisfied: opt-einsum==3.3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 38)) (3.3.0)
# Requirement already satisfied: pamela==1.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 39)) (1.0.0)
# Requirement already satisfied: pandas==1.3.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 40)) (1.3.5)
# Requirement already satisfied: pandas-datareader==0.10.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 41)) (0.10.0)
# Requirement already satisfied: patsy==0.5.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 42)) (0.5.3)
# Requirement already satisfied: Pillow==9.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 43)) (9.4.0)
# Requirement already satisfied: plotly==5.13.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 44)) (5.13.0)
# Requirement already satisfied: pyasn1==0.4.8 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 45)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 46)) (0.2.8)
# Requirement already satisfied: pyparsing==3.0.9 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 47)) (3.0.9)
# Requirement already satisfied: qtconsole==5.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 48)) (5.4.0)
# Requirement already satisfied: QtPy==2.3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 49)) (2.3.0)
# Requirement already satisfied: Quandl==3.7.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 50)) (3.7.0)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 51)) (1.3.1)
# Requirement already satisfied: rsa==4.9 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 52)) (4.9)
# Requirement already satisfied: scikit-learn==1.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 53)) (1.0.2)
# Requirement already satisfied: scipy==1.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 54)) (1.7.3)
# Requirement already satisfied: seaborn==0.12.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 55)) (0.12.2)
# Requirement already satisfied: statsmodels==0.13.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 56)) (0.13.5)
# Requirement already satisfied: tenacity==8.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 57)) (8.2.1)
# Requirement already satisfied: tensorboard==2.11.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 58)) (2.11.2)
# Requirement already satisfied: tensorflow==2.11.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 59)) (2.11.0)
# Requirement already satisfied: termcolor==2.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 60)) (2.2.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 61)) (3.1.0)
# Requirement already satisfied: webencodings==0.5.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 62)) (0.5.1)
# Requirement already satisfied: Werkzeug==2.2.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 63)) (2.2.2)
# Requirement already satisfied: wrapt==1.14.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 64)) (1.14.1)
# Requirement already satisfied: xlrd==2.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 65)) (2.0.1)
# Requirement already satisfied: yfinance==0.2.12 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from -r requirements.txt (line 66)) (0.2.12)
# Requirement already satisfied: six<2.0,>=1.6.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from astunparse==1.6.3->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from astunparse==1.6.3->-r requirements.txt (line 3)) (0.38.4)
# Requirement already satisfied: pyopenssl in /srv/conda/envs/notebook/lib/python3.7/site-packages (from certipy==0.1.3->-r requirements.txt (line 7)) (23.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Dash==2.8.1->-r requirements.txt (line 9)) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Dash==2.8.1->-r requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Dash==2.8.1->-r requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Dash==2.8.1->-r requirements.txt (line 9)) (2.2.3)
# Requirement already satisfied: nbconvert in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter==1.0.0->-r requirements.txt (line 24)) (7.2.9)
# Requirement already satisfied: ipywidgets in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter==1.0.0->-r requirements.txt (line 24)) (8.0.2)
# Requirement already satisfied: ipykernel in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter==1.0.0->-r requirements.txt (line 24)) (6.16.2)
# Requirement already satisfied: notebook in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter==1.0.0->-r requirements.txt (line 24)) (6.4.12)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-console==6.5.1->-r requirements.txt (line 25)) (3.0.36)
# Requirement already satisfied: ipython in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-console==6.5.1->-r requirements.txt (line 25)) (7.33.0)
# Requirement already satisfied: jupyter-client>=7.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-console==6.5.1->-r requirements.txt (line 25)) (7.4.9)
# Requirement already satisfied: traitlets>=5.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-console==6.5.1->-r requirements.txt (line 25)) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-console==6.5.1->-r requirements.txt (line 25)) (24.0.1)
# Requirement already satisfied: pygments in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-console==6.5.1->-r requirements.txt (line 25)) (2.14.0)
# Requirement already satisfied: typing-extensions in /srv/conda/envs/notebook/lib/python3.7/site-packages (from kiwisolver==1.4.4->-r requirements.txt (line 28)) (4.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Markdown==3.4.1->-r requirements.txt (line 31)) (4.11.4)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib==3.5.3->-r requirements.txt (line 32)) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib==3.5.3->-r requirements.txt (line 32)) (23.0)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas==1.3.5->-r requirements.txt (line 40)) (2022.7.1)
# Requirement already satisfied: requests>=2.19.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas-datareader==0.10.0->-r requirements.txt (line 41)) (2.28.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests-oauthlib==1.3.1->-r requirements.txt (line 51)) (3.2.2)
# Requirement already satisfied: setuptools>=41.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorboard==2.11.2->-r requirements.txt (line 58)) (67.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorboard==2.11.2->-r requirements.txt (line 58)) (0.6.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorboard==2.11.2->-r requirements.txt (line 58)) (3.19.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorboard==2.11.2->-r requirements.txt (line 58)) (1.8.1)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorflow==2.11.0->-r requirements.txt (line 59)) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorflow==2.11.0->-r requirements.txt (line 59)) (0.30.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Werkzeug==2.2.2->-r requirements.txt (line 63)) (2.1.1)
# Requirement already satisfied: cryptography>=3.3.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from yfinance==0.2.12->-r requirements.txt (line 66)) (38.0.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from yfinance==0.2.12->-r requirements.txt (line 66)) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.12->-r requirements.txt (line 66)) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cryptography>=3.3.2->yfinance==0.2.12->-r requirements.txt (line 66)) (1.15.1)
# Requirement already satisfied: click>=8.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Flask>=1.0.4->Dash==2.8.1->-r requirements.txt (line 9)) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Flask>=1.0.4->Dash==2.8.1->-r requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Flask>=1.0.4->Dash==2.8.1->-r requirements.txt (line 9)) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata>=4.4->Markdown==3.4.1->-r requirements.txt (line 31)) (3.12.0)
# Requirement already satisfied: debugpy>=1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 24)) (1.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 24)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 24)) (1.5.6)
# Requirement already satisfied: tornado>=6.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 24)) (6.2)
# Requirement already satisfied: psutil in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 24)) (5.9.3)
# Requirement already satisfied: jedi>=0.16 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython->jupyter-console==6.5.1->-r requirements.txt (line 25)) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython->jupyter-console==6.5.1->-r requirements.txt (line 25)) (4.8.0)
# Requirement already satisfied: decorator in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython->jupyter-console==6.5.1->-r requirements.txt (line 25)) (5.1.1)
# Requirement already satisfied: backcall in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython->jupyter-console==6.5.1->-r requirements.txt (line 25)) (0.2.0)
# Requirement already satisfied: pickleshare in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython->jupyter-console==6.5.1->-r requirements.txt (line 25)) (0.7.5)
# Requirement already satisfied: entrypoints in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-client>=7.0.0->jupyter-console==6.5.1->-r requirements.txt (line 25)) (0.4)
# Requirement already satisfied: wcwidth in /srv/conda/envs/notebook/lib/python3.7/site-packages (from prompt-toolkit>=3.0.30->jupyter-console==6.5.1->-r requirements.txt (line 25)) (0.2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.19.0->pandas-datareader==0.10.0->-r requirements.txt (line 41)) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.19.0->pandas-datareader==0.10.0->-r requirements.txt (line 41)) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.19.0->pandas-datareader==0.10.0->-r requirements.txt (line 41)) (3.4)
# Requirement already satisfied: widgetsnbextension~=4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 24)) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 24)) (3.0.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (1.5.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (2.0.4)
# Requirement already satisfied: nbformat>=5.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (5.7.3)
# Requirement already satisfied: bleach in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (6.0.0)
# Requirement already satisfied: tinycss2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (0.7.0)
# Requirement already satisfied: jupyterlab-pygments in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (0.2.2)
# Requirement already satisfied: defusedxml in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (0.7.1)
# Requirement already satisfied: terminado>=0.8.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 24)) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 24)) (1.8.0)
# Requirement already satisfied: prometheus-client in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 24)) (0.16.0)
# Requirement already satisfied: argon2-cffi in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 24)) (21.3.0)
# Requirement already satisfied: pycparser in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance==0.2.12->-r requirements.txt (line 66)) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jedi>=0.16->ipython->jupyter-console==6.5.1->-r requirements.txt (line 25)) (0.8.3)
# Requirement already satisfied: fastjsonschema in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (4.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pexpect>4.3->ipython->jupyter-console==6.5.1->-r requirements.txt (line 25)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /srv/conda/envs/notebook/lib/python3.7/site-packages (from argon2-cffi->notebook->jupyter==1.0.0->-r requirements.txt (line 24)) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (5.10.2)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (1.3.10)
# Requirement already satisfied: attrs>=17.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 24)) (22.2.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (67.4.0)
# Requirement already satisfied: werkzeug==2.2.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (2.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from werkzeug==2.2.2) (2.1.1)
# Requirement already satisfied: dash==2.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (2.8.1)
# Requirement already satisfied: dash-core-components==2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from dash==2.8.1) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from dash==2.8.1) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from dash==2.8.1) (5.13.0)
# Requirement already satisfied: Flask>=1.0.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from dash==2.8.1) (2.2.3)
# Requirement already satisfied: dash-table==5.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from dash==2.8.1) (5.0.0)
# Requirement already satisfied: itsdangerous>=2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Flask>=1.0.4->dash==2.8.1) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Flask>=1.0.4->dash==2.8.1) (3.1.2)
# Requirement already satisfied: click>=8.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Flask>=1.0.4->dash==2.8.1) (8.1.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Flask>=1.0.4->dash==2.8.1) (2.2.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Flask>=1.0.4->dash==2.8.1) (4.11.4)
# Requirement already satisfied: tenacity>=6.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from plotly>=5.0.0->dash==2.8.1) (8.2.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata>=3.6.0->Flask>=1.0.4->dash==2.8.1) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata>=3.6.0->Flask>=1.0.4->dash==2.8.1) (3.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash==2.8.1) (2.1.1)
# ERROR: Could not find a version that satisfies the requirement pkg_resources (from versions: none)
# ERROR: No matching distribution found for pkg_resources

# %% [markdown]
# Importing the packages needed

# %%
#import dash
#import dash_core_components as dcc
#import dash_html_components as html
#from dash.dependencies import Input,Output,State
#import pandas as pd
#import numpy as np
#import plotly.graph_objs as go
#import dash_daq as daq
from pickle import load
import cvxopt as opt
from cvxopt import blas, solvers

# %% [markdown]
# ### Load the data of the investors/individuals

# %%
# df.head()
os.chdir('../Data files for all Build Labs')
investors = pd.read_csv('InputData.csv', index_col = 0 )
os.chdir('../Build Lab 2c/')
investors.head(1)
# Out:
#    AGE07  EDCL07  MARRIED07  KIDS07  LIFECL07  OCCAT107      INCOME07  RISK07  \
# 0     47       2          1       0         2         1  56443.744181       3
#
#    WSAVED07  SPENDMOR07   NETWORTH07  TrueRiskTol
# 0         1           5  352641.7113     6.947439

# %% [markdown]
# ### Load the market data and clean the data

# %%
# df.head()
os.chdir('../Data files for all Build Labs')
assets = pd.read_csv('SP500Data.csv',index_col=0)
os.chdir('../Build Lab 2c/')
missing_fractions = assets.isnull().mean().sort_values(ascending=False)

missing_fractions.head(10)

drop_list = sorted(list(missing_fractions[missing_fractions > 0.3].index))

assets.drop(labels=drop_list, axis=1, inplace=True)
assets.shape
# Fill the missing values with the last value available in the dataset. 
assets=assets.fillna(method='ffill')
assets.head(2)
# Out:
#                   ABT       ABBV        ABMD         ACN       ATVI  \
# Date
# 2018-01-02  58.790001  98.410004  192.490005  153.839996  64.309998
# 2018-01-03  58.919998  99.949997  195.820007  154.550003  65.309998
#
#                   ADBE    AMD         AAP    AES         AMG  ...        WLTW  \
# Date                                                          ...
# 2018-01-02  177.699997  10.98  106.089996  10.88  203.039993  ...  146.990005
# 2018-01-03  181.039993  11.55  107.050003  10.87  202.119995  ...  149.740005
#
#                   WYNN        XEL        XRX       XLNX        XYL        YUM  \
# Date
# 2018-01-02  164.300003  47.810001  29.370001  67.879997  68.070000  81.599998
# 2018-01-03  162.520004  47.490002  29.330000  69.239998  68.900002  81.529999
#
#                    ZBH       ZION        ZTS
# Date
# 2018-01-02  124.059998  50.700001  71.769997
# 2018-01-03  124.919998  50.639999  72.099998
#
# [2 rows x 498 columns]

# %%
options=np.array(assets.columns)
# str(options)
options = []

for tic in assets.columns:
    #{'label': 'user sees', 'value': 'script sees'}
    mydict = {}
    mydict['label'] = tic #Apple Co. AAPL
    mydict['value'] = tic
    options.append(mydict)

# %% [markdown]
# <a id='2'></a>
# ## 2. Code for the dashboard Interface

# %%
app = dash.Dash(__name__, external_stylesheets=['https://codepen.io/chriddyp/pen/bWLwgP.css'])

# %%
app.layout = html.Div([
    html.Div([ 
        #Dashboard Name
        html.Div([
            html.H3(children='Robo Advisor Dashboard'),
            html.Div([
                html.H5(children='Step 1 : Enter Investor Characteristics '),            
                ],style={'display': 'inline-block','vertical-align': 'top',  'width': '30%',\
                         'color':'black', 'background-color': 'LightGray'}), 
            html.Div([
                html.H5(children='Step 2 : Asset Allocation and portfolio performance'),            
                ],style={'display': 'inline-block', 'vertical-align': 'top',  \
                         'color':'white','horizontalAlign' : "left", 'width': '70%', 'background-color':'black'}), 
            ],style={'font-family': 'calibri'}),        
         
         #All the Investor Characteristics
                      
       #********************Demographics Features DropDown********
         html.Div([   
          html.Div([ 
            
            html.Label('Age:',style={'padding': 5}),
            dcc.Slider(
                id='Age',
                min = investors['AGE07'].min(),
                max = 70,
                marks={ 25: '25',35: '35',45: '45',55: '55',70: '70'},              
                value=25),   
            #html.Br(),
            
            html.Label('NetWorth:', style={'padding': 5}),
            dcc.Slider(
                id='Nwcat',
                #min = investors['NETWORTH07'].min(), 
                min = -1000000, max = 3000000,
                marks={-1000000: '-$1M',0: '0',500000: '$500K',1000000: '$1M',2000000: '$2M',},                
                value=10000),
            #html.Br(),
            html.Label('Income:', style={'padding': 5}),
            dcc.Slider(
                id='Inccl',
                #min = investors['INCOME07'].min(), max = investors['INCOME07'].max(),
                min = -1000000,
                max = 3000000,
                marks={-1000000: '-$1M',0: '0',500000: '$500K',1000000: '$1M',2000000: '$2M',},
                value=100000),
            
           # html.Br(),
            html.Label('Education Level (scale of 4):', style={'padding': 5}),
            dcc.Slider(
                id='Edu',
                min = investors['EDCL07'].min(), max = investors['EDCL07'].max(),
                marks={ 1: '1',2: '2',3: '3',4: '4'},
                value=2), 
            #html.Br(),
            html.Label('Married:', style={'padding': 5}),
            dcc.Slider(
                id='Married',
                min = investors['MARRIED07'].min(), max = investors['MARRIED07'].max(),
                marks={ 1: '1',2: '2'},
                value=1), 
            #html.Br(),
            html.Label('Kids:', style={'padding': 5}),
            dcc.Slider(
                id='Kids',
                min = investors['KIDS07'].min(), max = investors['KIDS07'].max(),
                #marks={ 1: '1',2: '2',3: '3',4: '4'},
                marks=[{'label': j, 'value': j} for j in investors['KIDS07'].unique()],
                value=3), 
            #html.Br(),
            html.Label('Occupation:', style={'padding': 5}),
            dcc.Slider(
                id='Occ',
                min = investors['OCCAT107'].min(), max = investors['OCCAT107'].max(),
                marks={ 1: '1',2: '2',3: '3',4: '4'},
                value=3),            
            #html.Br(),
            html.Label('Willingness to take Risk:', style={'padding': 5}),
            dcc.Slider(
                id='Risk',
                min = investors['RISK07'].min(), max = investors['RISK07'].max(),
                marks={ 1: '1',2: '2',3: '3',4: '4'},
                value=3), 
            #html.Br(),
            html.Button(id='investor_char_button',
                            n_clicks = 0,
                            children = 'Calculate Risk Tolerance',
                            style = {'fontSize': 14, 'marginLeft': '30px', 'color' : 'white',\
                                     'horizontal-align': 'left','backgroundColor': 'grey'}),             
            #html.Br(),            
              ],style={'width': '80%'}),           
            
            ],style={'width': '30%', 'font-family': 'calibri','vertical-align': 'top','display': 'inline-block'\
                     }),
#                     , "border":".5px black solid"}),

    # ********************Risk Tolerance Charts********            
       html.Div([    
               #html.H5(children='Step 2 : Enter the Instruments for the allocation portfolio'),  
        html.Div([
            html.Div([ 
                html.Label('Risk Tolerance (scale of 100) :', style={'padding': 5}),
                dcc.Input(id= 'risk-tolerance-text'),
               
                ],style={'width': '100%','font-family': 'calibri','vertical-align': 'top','display': 'inline-block'}),

            html.Div([ 
                html.Label('Select the assets for the portfolio:', style={'padding': 5}),
                dcc.Dropdown(
                        id='ticker_symbol',
                        options = options,
                        value = ['GOOGL', 'FB', 'GS','MS','GE','MSFT'], 
                        multi = True
                        # style={'fontSize': 24, 'width': 75}
                        ),
                html.Button(id='submit-asset_alloc_button',
                            n_clicks = 0,
                            children = 'Submit',
                            style = {'fontSize': 12, 'marginLeft': '25px','color' : 'white', 'backgroundColor': 'grey'}

                ), 
               ],style={'width': '100%','font-family': 'calibri','vertical-align': 'top','display': 'inline-block'}),
            ],style={'width': '100%','display': 'inline-block','font-family': 'calibri','vertical-align': 'top'}),
           
           html.Div([                
                html.Div([
                    dcc.Graph(id='Asset-Allocation'), 
                    ], style={'width': '50%', 'vertical-align': 'top', 'display': 'inline-block', \
                      'font-family': 'calibri', 'horizontal-align': 'right'}),
                html.Div([
                    dcc.Graph(id='Performance')
                    ], style={'width': '50%', 'vertical-align': 'top', 'display': 'inline-block', \
                      'font-family': 'calibri', 'horizontal-align': 'right'}),
                   ], style={'width': '100%', 'vertical-align': 'top', 'display': 'inline-block', \
                          'font-family': 'calibri', 'horizontal-align': 'right'}),          


        ], style={'width': '70%','display': 'inline-block','font-family': 'calibri','vertical-align': 'top', 'horizontal-align': 'right'}),
       ],style={'width': '70%','display': 'inline-block','font-family': 'calibri','vertical-align': 'top'}),               

  ])

# %% [markdown]
# <a id='3'></a>
# ## 3. Code for the underlying functions within the interface
#
# The steps performed are as follows:
#
# 1) Loading the regression model for predicting risk tolerance
#
# 2) Using markovitz mean variance analysis for asset allocation
#
# 3) Producing chart for the asset allocation and portfolio performance
#
# #### Click the url produced by this code to see the dashboard

# %%
def predict_riskTolerance(X_input):

    filename = 'finalized_model.sav'
    loaded_model = load(open(filename, 'rb'))
    # estimate accuracy on validation set
    predictions = loaded_model.predict(X_input)
    return predictions

#Asset allocation given the Return, variance
def get_asset_allocation(riskTolerance,stock_ticker):
    #ipdb.set_trace()
    assets_selected = assets.loc[:,stock_ticker]
    return_vec = np.array(assets_selected.pct_change().dropna(axis=0)).T
    n = len(return_vec)
    returns = np.asmatrix(return_vec)
    mus = 1-riskTolerance
    
    # Convert to cvxopt matrices
    S = opt.matrix(np.cov(return_vec))
    pbar = opt.matrix(np.mean(return_vec, axis=1))
    # Create constraint matrices
    G = -opt.matrix(np.eye(n))   # negative n x n identity matrix
    h = opt.matrix(0.0, (n ,1))
    A = opt.matrix(1.0, (1, n))
    b = opt.matrix(1.0)
    # Calculate efficient frontier weights using quadratic programming
    portfolios = solvers.qp(mus*S, -pbar, G, h, A, b)
    w=portfolios['x'].T
    print (w)
    Alloc =  pd.DataFrame(data = np.array(portfolios['x']),index = assets_selected.columns)

    # Calculate efficient frontier weights using quadratic programming
    portfolios = solvers.qp(mus*S, -pbar, G, h, A, b)
    returns_final=(np.array(assets_selected) * np.array(w))
    returns_sum = np.sum(returns_final,axis =1)
    returns_sum_pd = pd.DataFrame(returns_sum, index = assets.index )
    returns_sum_pd = returns_sum_pd - returns_sum_pd.iloc[0,:] + 100   
    return Alloc,returns_sum_pd



#Callback for the graph
#This function takes all the inputs and computes the cluster and the risk tolerance


@app.callback(
     [Output('risk-tolerance-text', 'value')],
    [Input('investor_char_button', 'n_clicks'),
    Input('Age', 'value'),Input('Nwcat', 'value'),
    Input('Inccl', 'value'), Input('Risk', 'value'),
    Input('Edu', 'value'),Input('Married', 'value'),
    Input('Kids', 'value'),Input('Occ', 'value')])
#get the x and y axis details 

def update_risk_tolerance(n_clicks,Age,Nwcat,Inccl,Risk,Edu,Married,Kids,Occ):
      
    #ipdb.set_trace()
    
    RiskTolerance = 0
    if n_clicks != None:    
        X_input = [[Age,Edu,Married,Kids,Occ,Inccl, Risk,Nwcat]]
        RiskTolerance= predict_riskTolerance(X_input)
    #print(RiskAversion)
    #Using linear regression to get the risk tolerance within the cluster.    
    return list([round(float(RiskTolerance*100),2)])

@app.callback([Output('Asset-Allocation', 'figure'),
              Output('Performance', 'figure')],
            [Input('submit-asset_alloc_button', 'n_clicks'),
            Input('risk-tolerance-text', 'value')], 
            [State('ticker_symbol', 'value')
            ])
def update_asset_allocationChart(n_clicks, risk_tolerance, stock_ticker):
    
    Allocated, InvestmentReturn = get_asset_allocation(risk_tolerance,stock_ticker)  
    
    return [{'data' : [go.Bar(
                        x=Allocated.index,
                        y=Allocated.iloc[:,0],
                        marker=dict(color='red'),
                    ),
                    ],
            'layout': {'title':" Asset allocation - Mean-Variance Allocation"}

       },
            {'data' : [go.Scatter(
                        x=InvestmentReturn.index,
                        y=InvestmentReturn.iloc[:,0],
                        name = 'OEE (%)',
                        marker=dict(color='red'),
                    ),
                    ],
            'layout': {'title':"Portfolio value of $100 investment"}

       }]

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8050
# Press CTRL+C to quit

# %% [markdown]
# ## Sample Dashboard
#
# <img src="RoboDashboard.png" width="1400" />
